# %% [markdown]
# <a href="https://colab.research.google.com/github/Fahruddin002/Tugas-PCD-Segmentasi-Negatif-Contrast-Stretching-_F55122002_Fahruddin-A.Lebe/blob/main/Tugas_PCD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Transformasi Negatif**

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/content/mammogram.tiff")

# %%
img_1 = 255 - img

# %%
plt.subplot(2, 2, 1)
plt.imshow(img)
plt.title('Original Image')
plt.subplot(2, 2, 2)
plt.imshow(img_1)
plt.title('Image Negative')
# Out:
# Text(0.5, 1.0, 'Image Negative')

# %% [markdown]
# **contrast Stretching**

# %%
import numpy
import matplotlib.pyplot as plt
from copy import deepcopy
from PIL import Image

# %%
def getGreyColor(rgb):
    return rgb[0]

def setGrayColor(color):
    return [color, color, color]

# %%
img = Image.open('/content/lena.jpg')
img = numpy.asarray(img)

# %%
ct = deepcopy(img)

r1 = 100
s1 = 50
r2 = 150
s2 = 200

# %%
for i in range (len(img)):
    for j in range (len(img[i])):
        x = getGreyColor(img[i][j])
        if (0 <= x and x <= r1):
            ct[i][j] = setGrayColor(s1/r1*x)
        elif (r1 < x and x <= r2):
            ct[i][j] = setGrayColor(((s2-s1)/(r2-r1))*(x-r1)+s1)
        elif (r2 < x and x <= 255):
            ct[i][j] = setGrayColor(((255-s2)/(255-r2))*(x-r2)+s2)

# %%
plt.subplot(2,2,1)
plt.imshow(img)
plt.subplot(2,2,2)
plt.imshow(ct)
plt.show()
